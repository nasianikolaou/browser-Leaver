# %%
#20.07.2021
#
# open and read a tiff image
#

# %%
#use rasterio
# Install a conda package in the current Jupyter kernel
# import sys
# !conda install --yes --prefix {sys.prefix} rasterio
# Install a pip package in the current Jupyter kernel
#use rasterio
# Install a conda package in the current Jupyter kernel
# import sys
# !conda install --yes --prefix {sys.prefix} rasterio
# Install a pip package in the current Jupyter kernel
## (commands executed and commented out) import sys
## (commands executed and commented out) !{sys.executable} -m pip install rasterio

# %%
import numpy as np
import scipy as sp 
import rasterio
from rasterio.plot import show

# Great_Lakes.tif downloaded from browser (deprecated, not geolocated):
with rasterio.open("Great_Lakes.tif") as img:
    show(img)
    data = img.read()
# Out:
# /home/anikolaou/anaconda3/envs/py36/lib/python3.6/site-packages/rasterio/__init__.py:220: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
print ('*.Tif image is deprecated')
# Out:
# Tiff is deprecated
